# %%
import glob

from segmentation import *
from utils.image_io import prepare_image

import numpy as np



# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/shaharazulay/anaconda3/envs/dev/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['median', 'load', 'average']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
im = prepare_image('../deep-semantic-prior/double_dip/images/runner.jpg')
fg = prepare_image('../deep-semantic-prior/double_dip/saliency/output_fg/runner.jpg')
bg = prepare_image('../deep-semantic-prior/double_dip/saliency/output_bg/runner.jpg')

# %%
s = Segmentation(
    "runner", 
    im, 
    bg_hint=bg, 
    fg_hint=fg,
    plot_during_training=True,
    show_every=200,
    first_step_iter_num=500,
    second_step_iter_num=500,
    early_stop_psnr=30)

# %%
s.optimize()
# Out:
# Iteration   499 total_loss 0.089639 grad 2.349694 PSNR 21.350469

# %%
plot(s.learning_curve);

# %%
s.finalize()

# %%
s.finalize_first_step()
